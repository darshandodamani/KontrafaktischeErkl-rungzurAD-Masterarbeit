# %%
import numpy as np
from tensorflow.keras.utils import img_to_array
from keras.layers import Dense, Conv2D, MaxPooling2D, UpSampling2D
from keras.models import Sequential
import cv2
import matplotlib.pyplot as plt

# %%
img_data = []
img= cv2.imread('town7_000275.png')
#show image
plt.imshow(img)
#print actual size of the image
print(img.shape)
# Out:
# (80, 160, 3)

# %%
rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img_data.append(img_to_array(rgb_img))
img_final=img_data.astype('float32')/255
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_14098/3635188553.py in <module>
#       1 rgb_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       2 img_data.append(img_to_array(rgb_img))
# ----> 3 img_final=img_data.astype('float32')/255
#
# AttributeError: 'list' object has no attribute 'astype'
